# %%
# !pip install llama-index chromadb
# Out:
# ...
#      |████████████████████████████████| 628 kB 2.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.6 MB 20.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 23.5 MB/s eta 0:00:01
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# ...
#   Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# ...
#   Using cached pydantic-2.10.4-py3-none-any.whl (431 kB)
# ...
#      |████████████████████████████████| 2.4 MB 3.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 62 kB 2.0 MB/s  eta 0:00:01
# ...
#   Using cached posthog-3.7.5-py2.py3-none-any.whl (54 kB)
# ...
#      |████████████████████████████████| 6.4 MB 332 kB/s eta 0:00:011
# ...
#   Using cached opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
# ...
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# ...
#   Using cached opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# ...
#   Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
# ...

# %%
import sys
import os
sys.path.append('..')  # Adjust if needed to access your backend directory

from backend.setup_index import process_and_index

# Define paths (adjust these based on your project structure)
JSON_PATH = "backend/data/raw/uy-tourism.json"
STORAGE_PATH = "backend/data/chroma/"

# Create the storage directory if it doesn't exist
os.makedirs(STORAGE_PATH, exist_ok=True)

# Run the indexing process
process_and_index(JSON_PATH, STORAGE_PATH)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <module>
#       2 import os
#       3 sys.path.append('..')  # Adjust if needed to access your backend directory
# ----> 5 from backend.setup_index import process_and_index
#       7 # Define paths (adjust these based on your project structure)
#       8 JSON_PATH = "backend/data/raw/uy-tourism.json"
#
# File ~/uy-tourism/notebooks/../backend/setup_index.py:2, in <module>
#       1 import json
# ----> 2 from llama_index.core import Document
#       3 from llama_index.core import VectorStoreIndex
#       4 from llama_index.core import StorageContext
#
# File ~/.local/lib/python3.8/site-packages/llama_index/core/__init__.py:19, in <module>
#      15 from llama_index.core.embeddings.mock_embed_model import MockEmbedding
#      17 # indices
#      18 # loading
# ---> 19 from llama_index.core.indices import (
# ...
